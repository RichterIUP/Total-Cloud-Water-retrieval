# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir("/mnt/beegfs/user/phi.richter/OUTFOLDER_Calc_CRE/PS.20170611_141300.nc/6_12_12_48_57_74584")
wavenumber = pd.read_csv("wavenumber.csv")
radiance   = pd.read_csv("lbldis.csv")

# %%
plt.plot(wavenumber, radiance)
